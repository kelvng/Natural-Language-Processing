# %% [markdown]
# # Thực hành với Beam search
#
# Khôi phục dấu câu tiếng Việt sử dụng Beam search & Language model
#
# > Click vào ảnh để xem bài hướng dẫn chi tiết
#
# [![](https://nguyenvanhieu.vn/wp-content/uploads/2020/07/beam-search.jpg)](https://nguyenvanhieu.vn/thuat-toan-beam-search/)

# %%
import re
import json
import os
import itertools
from math import log

# %%
# Xóa dấu tiếng Việt
def remove_vn_accent(s):
    s = re.sub('[áàảãạăắằẳẵặâấầẩẫậ]', 'a', s)
    s = re.sub('[éèẻẽẹêếềểễệ]', 'e', s)
    s = re.sub('[óòỏõọôốồổỗộơớờởỡợ]', 'o', s)
    s = re.sub('[íìỉĩị]', 'i', s)
    s = re.sub('[úùủũụưứừửữự]', 'u', s)
    s = re.sub('[ýỳỷỹỵ]', 'y', s)
    s = re.sub('đ', 'd', s)
    return s

# %%
# Download VN syllables
# !wget -O vn_syllables.txt "https://gist.githubusercontent.com/nguyenvanhieuvn/8d7c3440590a6db732ef6e05498c1566/raw/0164ccb7094b22a48a52844e7fa748cf2820cec9/all-vietnamese-syllables.txt(G%25C3%25B5%2520d%25E1%25BA%25A5u%2520ki%25E1%25BB%2583u%2520c%25C5%25A9)"
# Download language model
# !wget "https://github.com/nguyenvanhieuvn/vn-accent-resoration/raw/master/vn_en_nextwords.txt.zip"
# !unzip vn_en_nextwords.txt.zip
# Download test data
# !wget "https://github.com/nguyenvanhieuvn/vn-accent-resoration/raw/master/test.txt"
# Out:
# --2021-01-12 06:53:54--  https://gist.githubusercontent.com/nguyenvanhieuvn/8d7c3440590a6db732ef6e05498c1566/raw/0164ccb7094b22a48a52844e7fa748cf2820cec9/all-vietnamese-syllables.txt(G%25C3%25B5%2520d%25E1%25BA%25A5u%2520ki%25E1%25BB%2583u%2520c%25C5%25A9)
# Resolving gist.githubusercontent.com (gist.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to gist.githubusercontent.com (gist.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116238 (114K) [text/plain]
# Saving to: ‘vn_syllables.txt’
#
# vn_syllables.txt    100%[===================>] 113.51K  --.-KB/s    in 0.04s
#
# 2021-01-12 06:53:54 (2.92 MB/s) - ‘vn_syllables.txt’ saved [116238/116238]
#
# --2021-01-12 06:53:54--  https://github.com/nguyenvanhieuvn/vn-accent-resoration/raw/master/vn_en_nextwords.txt.zip
# Resolving github.com (github.com)... 52.69.186.44
# Connecting to github.com (github.com)|52.69.186.44|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/nguyenvanhieuvn/beam-search-tutorial/raw/master/vn_en_nextwords.txt.zip [following]
# --2021-01-12 06:53:55--  https://github.com/nguyenvanhieuvn/beam-search-tutorial/raw/master/vn_en_nextwords.txt.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/nguyenvanhieuvn/beam-search-tutorial/master/vn_en_nextwords.txt.zip [following]
# --2021-01-12 06:53:55--  https://raw.githubusercontent.com/nguyenvanhieuvn/beam-search-tutorial/master/vn_en_nextwords.txt.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32146459 (31M) [application/zip]
# Saving to: ‘vn_en_nextwords.txt.zip’
#
# vn_en_nextwords.txt 100%[===================>]  30.66M   145MB/s    in 0.2s
#
# 2021-01-12 06:53:57 (145 MB/s) - ‘vn_en_nextwords.txt.zip’ saved [32146459/32146459]
#
# Archive:  vn_en_nextwords.txt.zip
#   inflating: vn_en_nextwords.txt
#   inflating: __MACOSX/._vn_en_nextwords.txt
# --2021-01-12 06:53:59--  https://github.com/nguyenvanhieuvn/vn-accent-resoration/raw/master/test.txt
# Resolving github.com (github.com)... 52.69.186.44
# Connecting to github.com (github.com)|52.69.186.44|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/nguyenvanhieuvn/beam-search-tutorial/raw/master/test.txt [following]
# --2021-01-12 06:53:59--  https://github.com/nguyenvanhieuvn/beam-search-tutorial/raw/master/test.txt
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/nguyenvanhieuvn/beam-search-tutorial/master/test.txt [following]
# --2021-01-12 06:53:59--  https://raw.githubusercontent.com/nguyenvanhieuvn/beam-search-tutorial/master/test.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 743554 (726K) [text/plain]
# Saving to: ‘test.txt’
#
# test.txt            100%[===================>] 726.13K  --.-KB/s    in 0.06s
#
# 2021-01-12 06:54:00 (12.5 MB/s) - ‘test.txt’ saved [743554/743554]

# %%
# Tạo bộ từ điển sinh dấu câu cho các từ không dấu
map_accents = {}
for word in open('vn_syllables.txt').read().splitlines():
  word = word.lower()
  no_accent_word = remove_vn_accent(word)
  if no_accent_word not in map_accents:
    map_accents[no_accent_word] = set()
  map_accents[no_accent_word].add(word)

# %%
print(map_accents['chac'])
# Out:
# {'chạc', 'chặc', 'chấc', 'chậc', 'chắc', 'chác'}

# %%
# Đọc lm
lm = {}
for line in open('vn_en_nextwords.txt'):
  data = json.loads(line)
  key = data['s']
  lm[key] = data
vocab_size = len(lm)
total_word = 0
for word in lm:
  total_word += lm[word]['sum']
print(vocab_size, total_word)
# Out:
# 50000 6343849795

# %%
lm['khang']
# Out:
# {'next': {'dinh': 1098296,
#   'chien': 79278,
#   'sinh': 47155,
#   'cao': 42236,
#   'trang': 29844,
#   'cu': 27689,
#   'nghi': 15900,
#   'khang': 15271,
#   'thuoc': 9327,
#   'the': 8145,
#   'an': 7981,
#   'cho': 5997,
#   'khuan': 5722,
#   'cua': 5562,
#   'khit': 5249,
#   'viem': 4357,
#   'và': 3153,
#   'va': 2963,
#   'đã': 2757,
#   'nguyen': 2586,
#   'voi': 2520,
#   'khai': 2513,
#   'lai': 2416,
#   'hy': 2033,
#   'virus': 1901,
#   'khiu': 1850,
#   'doi': 1608,
#   'thịnh': 1586,
#   'khong': 1556,
#   'benh': 1538,
#   'trong': 1529,
#   'điền': 1446,
#   'sau': 1327,
#   'rang': 1316,
#   'là': 1280,
#   'dân': 1263,
#   'nam': 1261,
#   'la': 1236,
#   'cũng': 1230,
#   'yeu': 1200,
#   'histamin': 1184,
#   'vi': 1184,
#   'việt': 1164,
#   'da': 1162,
#   'có': 1087,
#   'co': 1040,
#   'gia': 991,
#   'kem': 977,
#   'insulin': 964,
#   'tot': 942,
#   'minh': 917,
#   'thi': 899,
#   'duoc': 888,
#   'phó': 880,
#   'tu': 880,
#   'nhu': 875,
#   'dong': 840,
#   'chong': 833,
#   'do': 823,
#   'noi': 823,
#   'de': 801,
#   'được': 772,
#   'bị': 759,
#   'ha': 748,
#   'bao': 700,
#   'không': 696,
#   'ttxvn': 695,
#   'thông': 688,
#   'huy': 669,
#   'nhung': 669,
#   'theo': 667,
#   'cung': 658,
#   'manh': 655,
#   'sn': 649,
#   'con': 644,
#   'nguyên': 644,
#   'khi': 637,
#   'nuoc': 572,
#   'o': 549,
#   'còn': 548,
#   'giam': 548,
#   'sẽ': 547,
#   'phap': 546,
#   'nói': 541,
#   'đang': 528,
#   'nhat': 507,
#   'hang': 506,
#   'khác': 497,
#   'ninh': 497,
#   'cac': 495,
#   'quan': 492,
#   'nhieu': 491,
#   'virut': 481,
#   'truoc': 480,
#   'giu': 458,
#   'ma': 457,
#   'với': 456,
#   'chan': 453,
#   'quyet': 453,
#   'dien': 452,
#   'cùng': 446,
#   'nen': 440,
#   'tổng': 432,
#   'chia': 427,
#   'bang': 423,
#   'chi': 420,
#   'hay': 408,
#   'moi': 394,
#   'nao': 391,
#   'huyện': 388,
#   'mot': 387,
#   'làm': 386,
#   'vẫn': 384,
#   'lam': 383,
#   'rat': 378,
#   'giám': 375,
#   'oxy': 375,
#   'tren': 368,
#   'doc': 366,
#   'người': 365,
#   'ở': 365,
#   'anh': 363,
#   'chủ': 363,
#   'ca': 362,
#   'để': 359,
#   'histamine': 356,
#   'một': 354,
#   'thu': 354,
#   'ung': 354,
#   'tp': 353,
#   'duy': 352,
#   'bi': 351,
#   'tại': 346,
#   'khac': 340,
#   'nay': 339,
#   'ray': 336,
#   'hoac': 331,
#   'du': 329,
#   'linh': 325,
#   'phep': 323,
#   'hiv': 315,
#   'của': 304,
#   'noc': 304,
#   'phai': 300,
#   'về': 299,
#   'bac': 297,
#   'chu': 296,
#   'di': 295,
#   'cầu': 293,
#   'hoa': 293,
#   'se': 293,
#   'kien': 291,
#   'lại': 290,
#   'phu': 286,
#   'thì': 283,
#   'tinh': 268,
#   'chỉ': 265,
#   'thúy': 265,
#   'từng': 261,
#   'toi': 257,
#   'bat': 256,
#   'đến': 256,
#   'tang': 253,
#   've': 253,
#   'rất': 251,
#   'cựu': 249,
#   'phan': 249,
#   'ho': 247,
#   'ngay': 245,
#   'đi': 245,
#   'phải': 243,
#   'giup': 237,
#   'nguyễn': 236,
#   'tai': 236,
#   'từ': 235,
#   'đều': 234,
#   'acid': 232,
#   'giua': 232,
#   'thanh': 232,
#   'choi': 228,
#   'luôn': 226,
#   'ra': 226,
#   'phuong': 223,
#   'van': 223,
#   'muon': 222,
#   'nhan': 222,
#   'nu': 222,
#   'phong': 222,
#   'nhận': 220,
#   'qua': 219,
#   'dang': 216,
#   'chính': 215,
#   'dai': 214,
#   'danh': 213,
#   'hiện': 206,
#   'phường': 206,
#   'bui': 203,
#   'dau': 202,
#   'thái': 201,
#   'hi': 199,
#   'tri': 198,
#   'lenh': 196,
#   'quận': 194,
#   'thành': 193,
#   'corporation': 192,
#   'vừa': 191,
#   'buoc': 190,
#   'công': 190,
#   'hà': 190,
#   'trung': 189,
#   'ban': 188,
#   'ong': 188,
#   'trên': 187,
#   '2': 185,
#   'den': 182,
#   'thap': 182,
#   'lang': 180,
#   'mang': 180,
#   'chinh': 178,
#   'lan': 178,
#   'nguoi': 175,
#   'chung': 173,
#   'neu': 171,
#   'trưởng': 170,
#   'cai': 165,
#   'truong': 163,
#   'luc': 161,
#   'ông': 160,
#   'ảnh': 160,
#   '4': 159,
#   'lê': 159,
#   'vì': 159,
#   'ngày': 157,
#   'my': 156,
#   'thực': 156,
#   'bo': 154,
#   'vao': 154,
#   'mới': 153,
#   'dan': 152,
#   'huyen': 152,
#   'vĩnh': 152,
#   'tuyen': 151,
#   'vào': 151,
#   'chua': 150,
#   'lao': 150,
#   'như': 150,
#   'cuc': 149,
#   'nhưng': 149,
#   'tat': 149,
#   'day': 146,
#   'mà': 146,
#   'thai': 146,
#   'yên': 146,
#   'xã': 145,
#   'pho': 144,
#   'tiếp': 143,
#   'truc': 143,
#   'dung': 142,
#   'tham': 142,
#   'vo': 142,
#   'phát': 141,
#   'khiến': 140,
#   'phúc': 138,
#   'min': 137,
#   'thuc': 137,
#   'nguồn': 135,
#   'retrovirus': 134,
#   'su': 134,
#   'xin': 133,
#   'kha': 132,
#   '1': 131,
#   'bảo': 131,
#   'kể': 131,
#   'nghĩ': 131,
#   'boi': 130,
#   'khien': 129,
#   'ủy': 129,
#   'hoàng': 127,
#   'hóa': 127,
#   'mẫn': 127,
#   'quang': 126,
#   'thường': 126,
#   'ba': 125,
#   'cholinergic': 125,
#   'kỳ': 125,
#   'han': 124,
#   'thoi': 123,
#   'trở': 123,
#   'gi': 122,
#   'hạnh': 121,
#   '8': 120,
#   'cach': 120,
#   'đội': 120,
#   'axit': 119,
#   'nang': 119,
#   'p': 119,
#   'trước': 119,
#   'hiệu': 118,
#   'a': 117,
#   'chay': 117,
#   'suy': 117,
#   'viec': 117,
#   'can': 116,
#   'em': 116,
#   'gay': 116,
#   'đối': 116,
#   'mien': 115,
#   'ngan': 115,
#   'tự': 115,
#   'giap': 114,
#   'khu': 114,
#   'roi': 114,
#   '3': 113,
#   'chưa': 113,
#   'học': 113,
#   'xa': 113,
#   'giai': 111,
#   'nhau': 111,
#   'đưa': 111,
#   'vật': 110,
#   'giúp': 109,
#   'khẳng': 109,
#   'to': 109,
#   'q': 108,
#   'trần': 108,
#   'vitamin': 108,
#   'chiu': 107,
#   'tay': 107,
#   'thấy': 107,
#   'tôi': 106,
#   'dao': 105,
#   'no': 105,
#   'tamiflu': 105,
#   'dua': 104,
#   'toan': 104,
#   'hon': 103,
#   'này': 103,
#   'viết': 102,
#   'thay': 101,
#   'đồng': 101,
#   '6': 100,
#   'dieu': 100,
#   'hai': 100,
#   'sáng': 99,
#   'hoi': 97,
#   'kich': 97,
#   'phat': 97,
#   'các': 96,
#   'vua': 95,
#   'so': 94,
#   'dich': 93,
#   'huyet': 93,
#   'nham': 93,
#   'những': 93,
#   'tieu': 93,
#   'tranh': 93,
#   'nhã': 92,
#   'ke': 91,
#   'nha': 91,
#   'tuy': 90,
#   'tổ': 90,
#   'dac': 89,
#   'dược': 89,
#   'hữu': 89,
#   'lien': 88,
#   'phú': 88,
#   '5': 87,
#   'chat': 87,
#   'tâm': 87,
#   'đại': 87,
#   'bà': 86,
#   'lên': 86,
#   'nghe': 86,
#   'tran': 86,
#   'bắt': 85,
#   'dat': 85,
#   'nội': 85,
#   'quyết': 85,
#   'tử': 85,
#   'bách': 84,
#   'gây': 84,
#   'hlv': 84,
#   'son': 84,
#   'thuong': 83,
#   'thụy': 82,
#   'cong': 81,
#   'tro': 81,
#   'mua': 80,
#   'tài': 80,
#   'len': 79,
#   'nên': 79,
#   'xuất': 79,
#   'phạm': 78,
#   'ngoai': 77,
#   'song': 77,
#   'thuộc': 77,
#   '10': 76,
#   'dẫn': 76,
#   'khoe': 76,
#   'long': 76,
#   'lua': 76,
#   'man': 76,
#   'muốn': 76,
#   'nua': 76,
#   'tam': 76,
#   '7': 75,
#   'cuoi': 75,
#   'nhà': 75,
#   'tan': 74,
#   'tạm': 74,
#   'chị': 73,
#   'giải': 73,
#   'tin': 73,
#   'bình': 72,
#   'số': 72,
#   '11': 71,
#   'san': 71,
#   'viet': 71,
#   'xay': 71,
#   'suc': 70,
#   'trường': 70,
#   'châu': 69,
#   'duoi': 69,
#   'he': 69,
#   'hien': 69,
#   'ko': 69,
#   'lay': 69,
#   'loi': 69,
#   'nhi': 69,
#   'trái': 69,
#   'đạt': 69,
#   'ben': 68,
#   'biết': 68,
#   'chuyên': 68,
#   'deu': 68,
#   'liên': 68,
#   'lần': 68,
#   'mc': 68,
#   'tap': 68,
#   'tien': 68,
#   'y': 68,
#   'ap': 67,
#   'hỏi': 67,
#   'le': 67,
#   'năm': 67,
#   'tỉnh': 67,
#   'diễn': 66,
#   'methicillin': 66,
#   'viện': 66,
#   'bam': 65,
#   'cán': 65,
#   'dù': 65,
#   'gọi': 65,
#   'nho': 65,
#   'sang': 65,
#   'sản': 65,
#   'thong': 65,
#   'tiết': 65,
#   'bên': 64,
#   'khá': 64,
#   'loai': 64,
#   'luon': 64,
#   'mai': 64,
#   'mo': 64,
#   'nhân': 64,
#   'điều': 64,
#   'đứng': 64,
#   'cam': 63,
#   'dam': 63,
#   'dương': 63,
#   'mon': 63,
#   'nhiều': 63,
#   'nhấn': 63,
#   'tiet': 63,
#   'trả': 63,
#   'đảm': 63,
#   'kết': 62,
#   'vay': 62,
#   'đăng': 62,
#   '14': 61,
#   'chuyen': 61,
#   'dành': 61,
#   'ket': 61,
#   'tao': 61,
#   'tên': 61,
#   'yêu': 61,
#   'định': 61,
#   'cang': 60,
#   'cảm': 60,
#   'dùng': 60,
#   'kumite': 60,
#   'lúc': 60,
#   'vu': 60,
#   'vui': 60,
#   'androgen': 59,
#   'binh': 59,
#   'duong': 59,
#   'nhớ': 59,
#   'stress': 59,
#   'thể': 59,
#   'ton': 59,
#   '17': 58,
#   'ký': 58,
#   'ngoài': 58,
#   'thích': 58,
#   'tiep': 58,
#   '16': 57,
#   'báo': 57,
#   'chánh': 57,
#   'giữ': 57,
#   'khoi': 57,
#   'thien': 57,
#   'xuân': 57,
#   'chồng': 56,
#   'doan': 56,
#   'gặp': 56,
#   'lon': 56,
#   'vụ': 56,
#   '19': 55,
#   '21': 55,
#   'chiến': 55,
#   'cum': 55,
#   'lấy': 55,
#   'nhật': 55,
#   'vương': 55,
#   '23': 54,
#   'bỏ': 54,
#   'gửi': 54,
#   'nữ': 54,
#   'sot': 54,
#   '20': 53,
#   'kiện': 53,
#   'mong': 53,
#   'nằm': 53,
#   'phuc': 53,
#   'te': 53,
#   'tây': 53,
#   'vai': 53,
#   'việc': 53,
#   'địa': 53,
#   'don': 52,
#   'giao': 52,
#   'kieu': 52,
#   'mỗi': 52,
#   'ngọc': 52,
#   'chieu': 51,
#   'cô': 51,
#   'mvk': 51,
#   'mời': 51,
#   'tuong': 51,
#   'đề': 51,
#   '9': 50,
#   'coi': 50,
#   'h': 50,
#   'mac': 50,
#   'phân': 50,
#   'thứ': 50,
#   'trình': 50,
#   'ay': 49,
#   'chạy': 49,
#   'giới': 49,
#   'hieu': 49,
#   'hơn': 49,
#   'kim': 49,
#   'ky': 49,
#   'nhiet': 49,
#   'thang': 49,
#   'trao': 49,
#   '32': 48,
#   'cau': 48,
#   'gom': 48,
#   'mặc': 48,
#   'ngồi': 48,
#   'tram': 48,
#   'tre': 48,
#   'đây': 48,
#   '18': 47,
#   'gan': 47,
#   'gần': 47,
#   'hau': 47,
#   'hát': 47,
#   'ngụ': 47,
#   'nấn': 47,
#   'trú': 47,
#   'u': 47,
#   'vốn': 47,
#   '12': 46,
#   '22': 46,
#   '30': 46,
#   'him': 46,
#   'hưu': 46,
#   'lý': 46,
#   'sieu': 46,
#   '15': 45,
#   'bày': 45,
#   'dự': 45,
#   'luân': 45,
#   'mỹ': 45,
#   'phim': 45,
#   'phối': 45,
#   'tong': 45,
#   'tra': 45,
#   'tung': 45,
#   'đóng': 45,
#   'đường': 45,
#   '07': 44,
#   'bất': 44,
#   'canh': 44,
#   'chọn': 44,
#   'cần': 44,
#   'keo': 44,
#   'kho': 44,
#   'nhanh': 44,
#   'nếu': 44,
#   'quốc': 44,
#   'thiên': 44,
#   'thừa': 44,
#   'vô': 44,
#   'ơi': 44,
#   '45': 43,
#   'bài': 43,
#   'bí': 43,
#   'chang': 43,
#   'rut': 43,
#   'ten': 43,
#   'estrogen': 42,
#   'hanh': 42,
#   'hàng': 42,
#   'quyen': 42,
#   'rồi': 42,
#   'tru': 42,
#   'artemisinin': 41,
#   'ngoi': 41,
#   'tới': 41,
#   'văn': 41,
#   'bé': 40,
#   'nhìn': 40,
#   'nhạc': 40,
#   'tiến': 40,
#   'xem': 40,
#   'đặt': 40,
#   '55': 39,
#   'bien': 39,
#   'bán': 39,
#   'cha': 39,
#   'cham': 39,
#   'hưng': 39,
#   'hết': 39,
#   'kigona': 39,
#   'lat': 39,
#   'lâm': 39,
#   'thật': 39,
#   'toàn': 39,
#   'vinh': 39,
#   'cười': 38,
#   'cầm': 38,
#   'kmedia': 38,
#   'may': 38,
#   'ngo': 38,
#   'nhe': 38,
#   'quyền': 38,
#   'quảng': 38,
#   'tức': 38,
#   'đơn': 38,
#   '06': 37,
#   '70': 37,
#   'bridal': 37,
#   'chết': 37,
#   'goi': 37,
#   'kinh': 37,
#   'lap': 37,
#   'nổi': 37,
#   'trụ': 37,
#   'tình': 37,
#   'đức': 37,
#   '37': 36,
#   'ai': 36,
#   'cat': 36,
#   'cty': 36,
#   'dc': 36,
#   'hoan': 36,
#   'mau': 36,
#   'me': 36,
#   'mi': 36,
#   'mất': 36,
#   'sử': 36,
#   'tac': 36,
#   'tỏ': 36,
#   'đó': 36,
#   'đầu': 36,
#   'bạn': 35,
#   'chiều': 35,
#   'chon': 35,
#   'hom': 35,
#   'it': 35,
#   'muc': 35,
#   'phương': 35,
#   'quay': 35,
#   'tuc': 35,
#   'vien': 35,
#   'vũ': 35,
#   '50': 34,
#   'chàng': 34,
#   'chăm': 34,
#   'chơi': 34,
#   'giong': 34,
#   'het': 34,
#   'hồng': 34,
#   'mat': 34,
#   'mằn': 34,
#   'sở': 34,
#   'thpt': 34,
#   'thue': 34,
#   'tư': 34,
#   'von': 34,
#   'vạn': 34,
#   'ý': 34,
#   'canxi': 33,
#   'cứ': 33,
#   'dap': 33,
#   'ding': 33,
#   'hoc': 33,
#   'lập': 33,
#   'phụ': 33,
#   'đánh': 33,
#   '24': 32,
#   'am': 32,
#   'bai': 32,
#   'càng': 32,
#   'cơ': 32,
#   'hoàn': 32,
#   'ks': 32,
#   'mở': 32,
#   'ngô': 32,
#   'nsưt': 32,
#   'sắp': 32,
#   'thị': 32,
#   'trực': 32,
#   'tìm': 32,
#   '25': 31,
#   'bộ': 31,
#   'chau': 31,
#   'cách': 31,
#   'cậu': 31,
#   'giá': 31,
#   'giả': 31,
#   'hồ': 31,
#   'lừa': 31,
#   'nga': 31,
#   'on': 31,
#   '62': 30,
#   'bức': 30,
#   'chụp': 30,
#   'cmn': 30,
#   'dinhh': 30,
#   'gio': 30,
#   'keu': 30,
#   'lưu': 30,
#   'nợ': 30,
#   'quen': 30,
#   'rằng': 30,
#   'rủ': 30,
#   'xuong': 30,
#   'ăn': 30,
#   '27': 29,
#   'bon': 29,
#   'chac': 29,
#   'chiếm': 29,
#   'giờ': 29,
#   'h2': 29,
#   'hải': 29,
#   'ly': 29,
#   'nhóm': 29,
#   'trichoderma': 29,
#   'trẻ': 29,
#   'bay': 28,
#   'chúc': 28,
#   'ghi': 28,
#   'hiếm': 28,
#   'hiền': 28,
#   'hoang': 28,
#   'hòa': 28,
#   'lac': 28,
#   'nghiệp': 28,
#   'nhiem': 28,
#   'nơi': 28,
#   'om': 28,
#   'quy': 28,
#   'quê': 28,
#   'rocker': 28,
#   'thich': 28,
#   'tạo': 28,
#   'đâu': 28,
#   'đọc': 28,
#   '26': 27,
#   '29': 27,
#   '42': 27,
#   '55kg': 27,
#   'buc': 27,
#   'cay': 27,
#   'chẳng': 27,
#   'gồm': 27,
#   'huu': 27,
#   'hôm': 27,
#   'lớp': 27,
#   'nghệ': 27,
#   'nó': 27,
#   'penicillin': 27,
#   's': 27,
#   'ta': 27,
#   'thế': 27,
#   'thời': 27,
#   'tập': 27,
#   'vuot': 27,
#   'xuat': 27,
#   'đem': 27,
#   'đặc': 27,
#   '46': 26,
#   'bệnh': 26,
#   'bỗng': 26,
#   'chuẩn': 26,
#   'cả': 26,
#   'lau': 26,
#   'nhin': 26,
#   'pham': 26,
#   'que': 26,
#   'tú': 26,
#   '48': 25,
#   '71': 25,
#   'arv': 25,
#   'cuoc': 25,
#   'din': 25,
#   'glivec': 25,
#   'lương': 25,
#   'media': 25,
#   'mạnh': 25,
#   'ngu': 25,
#   'ngân': 25,
#   'nhom': 25,
#   'quoc': 25,
#   'tau': 25,
#   'thêm': 25,
#   'tim': 25,
#   'trương': 25,
#   'uong': 25,
#   '28': 24,
#   'bach': 24,
#   'bieu': 24,
#   'bu': 24,
#   'bởi': 24,
#   'chào': 24,
#   'chắc': 24,
#   'chở': 24,
#   'cường': 24,
#   'ep': 24,
#   'hn': 24,
#   'khoảng': 24,
#   'kiem': 24,
#   'lanh': 24,
#   'liền': 24,
#   'lãnh': 24,
#   'nhac': 24,
#   'taekwondo': 24,
#   'tho': 24,
#   'đúng': 24,
#   'đạo': 24,
#   'đỗ': 24,
#   'bùi': 23,
#   'bằng': 23,
#   'che': 23,
#   'chuyển': 23,
#   'chương': 23,
#   'doanh': 23,
#   'huỳnh': 23,
#   'hứa': 23,
#   'khan': 23,
#   'ngam': 23,
#   'nhập': 23,
#   'nut': 23,
#   'quá': 23,
#   'sao': 23,
#   'sự': 23,
#   'tgđ': 23,
#   'thiết': 23,
#   'tốt': 23,
#   'uon': 23,
#   'vung': 23,
#   'vợ': 23,
#   'xác': 23,
#   'đoạt': 23,
#   'ấn': 23,
#   '05': 22,
#   '60kg': 22,
#   '61': 22,
#   'bác': 22,
#   'chúng': 22,
#   'chấn': 22,
#   'càn': 22,
#   'giật': 22,
#   'giữa': 22,
#   'h1': 22,
#   'khải': 22,
#   'nghỉ': 22,
#   'nhé': 22,
#   'nhảy': 22,
#   'nắm': 22,
#   'phản': 22,
#   'that': 22,
#   'thua': 22,
#   'thuy': 22,
#   'thắt': 22,
#   'tạ': 22,
#   'ubnd': 22,
#   'vat': 22,
#   'đinh': 22,
#   'đón': 22,
#   '1876': 21,
#   'cố': 21,
#   'giang': 21,
#   'hong': 21,
#   'hoài': 21,
#   'hào': 21,
#   'k': 21,
#   'kêu': 21,
#   'phi': 21,
#   'ro': 21,
#   'thùy': 21,
#   'tphcm': 21,
#   'triều': 21,
#   'tân': 21,
#   'uy': 21,
#   'vy': 21,
#   'xe': 21,
#   'điện': 21,
#   'đặng': 21,
#   '100': 20,
#   '40': 20,
#   '56': 20,
#   '60': 20,
#   'bước': 20,
#   'gianh': 20,
#   'hamlet': 20,
#   'huong': 20,
#   'karaoke': 20,
#   'lo': 20,
#   'lực': 20,
#   'mma': 20,
#   'ngã': 20,
#   'sai': 20,
#   'sơn': 20,
#   'tanding': 20,
#   'tnl': 20,
#   'tặng': 20,
#   'chiem': 19,
#   'cholin': 19,
#   'dance': 19,
#   'giành': 19,
#   'hội': 19,
#   'khánh': 19,
#   'luan': 19,
#   'mitsubishi': 19,
#   'mộc': 19,
#   'nêu': 19,
#   'pv': 19,
#   'sống': 19,
#   'than': 19,
#   'them': 19,
#   'thí': 19,
#   'tnf': 19,
#   'trọng': 19,
#   'tác': 19,
#   'võ': 19,
#   'yến': 19,
#   'đoàn': 19,
#   '904': 18,
#   'chữa': 18,
#   'd': 18,
#   'dễ': 18,
#   'goc': 18,
#   'gđ': 18,
#   'hỗ': 18,
#   'insuline': 18,
#   'khóc': 18,
#   'khởi': 18,
#   'luong': 18,
#   'lái': 18,
#   'mọi': 18,
#   'nhằm': 18,
#   'nhờ': 18,
#   'niên': 18,
#   'nữa': 18,
#   'phospholipid': 18,
#   'photo': 18,
#   'quán': 18,
#   'sớm': 18,
#   't': 18,
#   'thuê': 18,
#   'thôi': 18,
#   'tia': 18,
#   'villa': 18,
#   ...},
#  's': 'khang',
#  'sum': 1584705}

# %%
# tính xác suất dùng smoothing
def get_proba(current_word, next_word):
  if current_word not in lm:
    return 1 / total_word;
  if next_word not in lm[current_word]['next']:
    return 1 / (lm[current_word]['sum'] + vocab_size)
  return (lm[current_word]['next'][next_word] + 1) / (lm[current_word]['sum'] + vocab_size)

# def get_proba(current_word, next_word):
#   try:
#     return (lm[current_word]['next'][next_word]) / (lm[current_word]['sum'])
#   except:
#     return 1e-30

# %%
# hàm beam search
def beam_search(words, k=3):
  sequences = []
  for idx, word in enumerate(words):
    if idx == 0:
      sequences = [([x], 0.0) for x in map_accents.get(word, [word])]
    else:
      all_sequences = []
      for seq in sequences:
        for next_word in map_accents.get(word, [word]):
          current_word = seq[0][-1]
          proba = get_proba(current_word, next_word)
          # print(current_word, next_word, proba, log(proba))
          proba = log(proba)
          new_seq = seq[0].copy()
          new_seq.append(next_word)
          all_sequences.append((new_seq, seq[1] + proba))
      # print(all_sequences) 
      all_sequences = sorted(all_sequences,key=lambda x: x[1], reverse=True)
      sequences = all_sequences[:k]
  return sequences

# %%
# tiền xử lý text
def preprocess(sentence):
  sentence = sentence.lower()
  sentence = re.sub(r'[.,~`!@#$%\^&*\(\)\[\]\\|:;\'"]+', ' ', sentence)
  sentence = re.sub(r'\s+', ' ', sentence).strip()
  return sentence

# %%
# test 1 câu
sentence = "Tuy nhiên giai đoạn từ 2009 đến ngày 15/10/2017 công ty không còn thực hiện các  trang"
sentence = preprocess(sentence)
_sentence = remove_vn_accent(sentence)
words = _sentence.split()
results = beam_search(words, k=5)
print('INP:', sentence)

print('OUT:', ' '.join(results[0][0]))
print('CMP:', ' '.join(results[0][0]) == sentence)
# Out:
# INP: tuy nhiên giai đoạn từ 2009 đến ngày 15/10/2017 công ty không còn thực hiện các trang
# OUT: tuy nhiên giai đoạn từ 2009 đến ngày 15/10/2017 công ty không còn thực hiện các trang
# CMP: True

# %%
# test qua bộ test ~ 5000 câu
k = 10
sentences = open('test.txt').read().splitlines()
test_size = len(sentences)
print(test_size)
correct = 0
for sent in sentences:
  try:
    sent = preprocess(sent)
    _sent = remove_vn_accent(sent)
    words = _sent.split()
    results = beam_search(words, k)
    if ' '.join(results[0][0]) == sent:
      correct += 1
  except:
    print('err', sent)
    break

print(correct / test_size)
# Out:
# 4983
# 0.32691149909692957
