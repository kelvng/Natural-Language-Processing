# %% [markdown]
# # Import Library

# %%
import numpy as np
from collections import Counter
import math
from nltk.translate.bleu_score import sentence_bleu
import nltk
nltk.download('punkt')

# %%
# !pip install -U pip
# !pip install -U dill
# !pip install -U nltk==3.5
# Out:
# Requirement already up-to-date: pip in /usr/local/lib/python3.6/dist-packages (20.2.2)
# Requirement already up-to-date: dill in /usr/local/lib/python3.6/dist-packages (0.3.2)
# Requirement already up-to-date: nltk==3.5 in /usr/local/lib/python3.6/dist-packages (3.5)
# Requirement already satisfied, skipping upgrade: click in /usr/local/lib/python3.6/dist-packages (from nltk==3.5) (7.1.2)
# Requirement already satisfied, skipping upgrade: regex in /usr/local/lib/python3.6/dist-packages (from nltk==3.5) (2019.12.20)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.6/dist-packages (from nltk==3.5) (4.41.1)
# Requirement already satisfied, skipping upgrade: joblib in /usr/local/lib/python3.6/dist-packages (from nltk==3.5) (0.16.0)
# Requirement already satisfied: pyvi in /usr/local/lib/python3.6/dist-packages (0.1)
# Requirement already satisfied: sklearn-crfsuite in /usr/local/lib/python3.6/dist-packages (from pyvi) (0.3.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from pyvi) (0.22.2.post1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite->pyvi) (1.15.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite->pyvi) (4.41.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite->pyvi) (0.8.7)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /usr/local/lib/python3.6/dist-packages (from sklearn-crfsuite->pyvi) (0.9.7)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->pyvi) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->pyvi) (0.16.0)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->pyvi) (1.4.1)

# %% [markdown]
# # Bài 1:
#
# ### Thêm phương pháp Good Turing smoothing vào mô hình ngôn ngữ 1-gram, 2-gram, 3-gram

# %%
# !wget "https://raw.githubusercontent.com/nthanhkhang/Natural-Language-Processing/main/Lecture%202%20Language%20Models/HW2_F17_NLP6320-NLPCorpusTreebank2Parts-CorpusA-Unix.txt"
def readData(fileName):
	data = []
	file = open(fileName, "r")
	for word in file.read().split():
		data.append(word)
	file.close()
	return data
# Out:
# --2021-01-18 15:59:12--  https://raw.githubusercontent.com/nthanhkhang/Natural-Language-Processing/main/Lecture%202%20Language%20Models/HW2_F17_NLP6320-NLPCorpusTreebank2Parts-CorpusA-Unix.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 161867 (158K) [text/plain]
# Saving to: ‘HW2_F17_NLP6320-NLPCorpusTreebank2Parts-CorpusA-Unix.txt’
#
# HW2_F17_NLP6320-NLP 100%[===================>] 158.07K  --.-KB/s    in 0.01s
#
# 2021-01-18 15:59:12 (12.1 MB/s) - ‘HW2_F17_NLP6320-NLPCorpusTreebank2Parts-CorpusA-Unix.txt’ saved [161867/161867]

# %%
def createBigram(data):
	listOfBigrams = []
	bigramCounts = {}
	unigramCounts = {}
	nbyn = {}
	for i in range(len(data)):
		if i < len(data) - 1:
			listOfBigrams.append((data[i], data[i + 1]))
			if (data[i], data[i+1]) in bigramCounts:
				bigramCounts[(data[i], data[i + 1])] += 1
			else:
				bigramCounts[(data[i], data[i + 1])] = 1
		if data[i] in unigramCounts:
			unigramCounts[data[i]] += 1
		else:
			unigramCounts[data[i]] = 1
	return listOfBigrams, unigramCounts, bigramCounts

# %%
# ------------------------------ Simple Bigram Model --------------------------------
def calcBigramProb(listOfBigrams, unigramCounts, bigramCounts):

	listOfProb = {}
	for bigram in listOfBigrams:
		word1 = bigram[0]
		word2 = bigram[1]
		listOfProb[bigram] = (bigramCounts.get(bigram))/(unigramCounts.get(word1))
	return listOfProb

# %%
# ------------------------------- Add One Smoothing ---------------------------------
def addOneSmothing(listOfBigrams, unigramCounts, bigramCounts):
	listOfProb = {}
	cStar = {}
	for bigram in listOfBigrams:
		word1 = bigram[0]
		word2 = bigram[1]
		listOfProb[bigram] = (bigramCounts.get(bigram) + 1)/(unigramCounts.get(word1) + len(unigramCounts))
		cStar[bigram] = (bigramCounts[bigram] + 1) * unigramCounts[word1] / (unigramCounts[word1] + len(unigramCounts))
	return listOfProb, cStar

# %%
def goodTuringDiscounting(listOfBigrams, bigramCounts, totalNumberOfBigrams):
	listOfProb = {}
	bucket = {}
	bucketList = []
	cStar = {}
	pStar = {}
	listOfCounts = {}
	i = 1
	for bigram in bigramCounts.items():
		key = bigram[0]
		value = bigram[1]
		
		if not value in bucket:
			bucket[value] = 1
		else:
			bucket[value] += 1	
	bucketList = sorted(bucket.items() , key=lambda t : t[0])
	zeroOccurenceProb = bucketList[0][1] / totalNumberOfBigrams
	lastItem = bucketList[len(bucketList)-1][0]
	for x in range(1, lastItem):
		if x not in bucket:
			bucket[x] = 0
	bucketList = sorted(bucket.items() , key=lambda t : t[0])
	lenBucketList = len(bucketList)
	for k, v in bucketList:
		if i < lenBucketList-1:
			if v == 0:
				cStar[k] = 0
				pStar[k] = 0
			else:
				cStar[k] = (i+1) * bucketList[i][1] / v
				pStar[k] = cStar[k] / totalNumberOfBigrams
		else:
			cStar[k] = 0
			pStar[k] = 0
		i += 1
	for bigram in listOfBigrams:
		listOfProb[bigram] = pStar.get(bigramCounts[bigram])
		listOfCounts[bigram] = cStar.get(bigramCounts[bigram])
	return listOfProb, zeroOccurenceProb, listOfCounts

# %%
if __name__ == '__main__':
	fileName = 'HW2_F17_NLP6320-NLPCorpusTreebank2Parts-CorpusA-Unix.txt'
	data = readData(fileName)
	listOfBigrams, unigramCounts, bigramCounts = createBigram(data)
	bigramProb = calcBigramProb(listOfBigrams, unigramCounts, bigramCounts)
	bigramAddOne, addOneCstar = addOneSmothing(listOfBigrams, unigramCounts, bigramCounts)
	bigramGoodTuring, zeroOccurenceProb, goodTuringCstar = goodTuringDiscounting(listOfBigrams, bigramCounts, len(listOfBigrams))

	# ------------------------------------- Testing --------------------------------------
	input = "Richard W. Lock , retired vice president and treasurer of"
	inputList = []
	outputProb1 = 1
	outputProb2 = 1
	outputProb3 = 1
	for i in range(len(input.split())-1):
		inputList.append((input.split()[i], input.split()[i+1]))
	print (inputList)
	# ------------------------------ Simple Bigram Model --------------------------------
	for i in range(len(inputList)):
		if inputList[i] in bigramProb:
			outputProb1 *= bigramProb[inputList[i]]
		else:
			outputProb1 *= 0

	print ('Bigram Model: ', outputProb1)

	# ------------------------------- Add One Smoothing ---------------------------------
	for i in range(len(inputList)):
		if inputList[i] in bigramAddOne:
			outputProb2 *= bigramAddOne[inputList[i]]
		else:
			if inputList[i][0] not in unigramCounts:
				unigramCounts[inputList[i][0]] = 1
			prob = (1) / (unigramCounts[inputList[i][0]] + len(unigramCounts))
			addOneCStar = 1 * unigramCounts[inputList[i][0]] / (unigramCounts[inputList[i][0]] + len(unigramCounts))
			outputProb2 *= prob
	print ('Add One: ', outputProb2)

	# ---------------------------- Good Turing Discounting ------------------------------
	for i in range(len(inputList)):
		if inputList[i] in bigramGoodTuring:
			outputProb3 *= bigramGoodTuring[inputList[i]]
		else:
			outputProb3 *= zeroOccurenceProb
	print ('Good Turing: ' , outputProb3)
# Out:
# [('Richard', 'W.'), ('W.', 'Lock'), ('Lock', ','), (',', 'retired'), ('retired', 'vice'), ('vice', 'president'), ('president', 'and'), ('and', 'treasurer'), ('treasurer', 'of')]
# Bigram Model:  1.3484074717156563e-10
# Add One:  4.602394835477551e-29
# Good Turing:  1.906026590289504e-40

# %% [markdown]
# # Bài 2:
# ### Nhập vào 3 từ đầu tiên của một câu, sinh thêm N từ tiếp theo (N tự đưa vào)

# %% [markdown]
# ## Download data

# %%
# !wget https://github.com/nthanhkhang/Natural-Language-Processing/blob/main/Data/Train_Full.zip
# !unzip /content/Train_Full.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11395).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11396).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11398).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11399).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11400).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11401).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11405).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11412).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11413).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11414).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11415).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11417).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11418).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11419).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11421).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11423).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11425).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11427).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11429).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11430).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11431).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11432).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11433).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11434).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11435).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11720).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11721).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11722).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11723).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11724).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11726).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11727).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11728).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11729).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11730).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11731).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11732).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11736).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11738).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11739).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11740).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11741).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11742).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11743).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11744).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11745).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11748).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11750).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11751).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11752).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11753).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11754).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11755).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11757).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11758).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11759).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11760).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11761).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11762).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11763).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11764).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11765).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11766).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11767).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11768).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11769).txt
#   inflating: Train_Full/Van hoa/VH_TN_T_ (11770).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11210).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11214).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11217).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11221).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11223).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11224).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11225).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11227).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11230).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11231).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11233).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11234).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11236).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11237).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11242).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11243).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11244).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11245).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11246).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11248).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11249).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11250).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11251).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11252).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11253).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11256).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11257).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11258).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11259).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11260).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11261).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11262).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11264).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11266).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11267).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11268).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11269).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11270).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11271).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11274).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11275).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11276).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11277).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11278).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11279).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11281).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11283).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11284).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11285).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11286).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11287).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11290).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11291).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11292).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11293).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11294).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11295).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11296).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11298).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11300).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11305).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11306).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11307).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11308).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11309).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11310).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11311).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11312).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11313).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11314).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11715).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11716).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11717).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11718).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11719).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11720).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11721).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11722).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11723).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11724).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11725).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11726).txt
#   inflating: Train_Full/Van hoa/VH_TT_T_ (11727).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1000).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10000).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10001).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10004).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10005).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10008).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1001).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10010).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10011).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10013).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10014).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10018).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10019).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1002).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10021).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10023).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10025).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10027).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1003).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10032).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10034).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10038).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1004).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10043).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10045).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10048).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10049).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1005).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10051).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10054).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10091).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10093).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10097).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10099).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1010).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10101).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10102).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10104).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10109).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1011).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10111).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10112).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10115).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10116).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10118).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10123).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10124).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10127).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1013).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10131).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10134).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10136).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1014).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10140).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10141).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10144).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10146).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10147).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10149).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1015).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10151).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10152).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10155).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10156).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10158).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1016).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10160).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10163).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10165).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10167).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10169).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1017).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10172).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10174).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10177).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10178).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1018).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10180).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10182).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10184).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10186).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10188).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10189).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1019).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10192).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10194).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10196).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10198).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1020).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10200).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10203).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10204).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10206).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10208).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1021).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10210).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10213).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10215).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10218).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1022).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10220).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10222).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10225).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1023).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10230).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10232).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10234).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10236).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10237).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10239).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (1024).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10242).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (10243).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (
txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9855).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9857).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9860).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9862).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9866).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9867).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9869).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (987).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9872).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9873).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9875).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9878).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (988).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9880).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9885).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9887).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9889).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (989).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9891).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9893).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9895).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9898).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (99).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (990).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9900).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9901).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9903).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9905).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9907).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (991).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9910).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9911).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9916).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9917).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (992).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9920).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9921).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9924).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9926).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9928).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (993).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9930).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9933).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9934).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9936).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9938).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (994).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9941).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9944).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9947).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9949).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (995).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9950).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9952).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9954).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9959).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (996).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9961).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9962).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9965).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9967).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9968).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (997).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9970).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9973).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9975).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9976).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9979).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (998).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9980).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9982).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9985).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9986).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9988).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (999).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9991).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9992).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9995).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9997).txt
#   inflating: Train_Full/Van hoa/VH_VNE_T_ (9998).txt

# %%
import os

full = []
for dirname, _, filenames in os.walk('/content/Train_Full'):
    for filename in filenames:
        # print(os.path.join(dirname, filename))
        with open(os.path.join("/content", os.path.join(dirname, filename)), 'r', encoding='UTF-16') as f:
            full.append(f.read())

print(len(full))
# Out:
# 42744

# %%
full[13]
# Out:
# 'Rụng tóc nhiều ở nữ\n"Cháu đang học lớp 11, kinh nguyệt bình thường, đầu không ngứa, nhưng không hiểu vì sao 5-6 tháng nay tóc của cháu bị rụng rất nhiều. Xin bác sĩ cho biết cháu bị bệnh gì? Nên ăn những chất gì và giữ gìn tóc thế nào để không bị rụng nhiều nữa?".Trả lời: \nNhiều em gái ở độ tuổi cháu cũng bị rụng tóc như vậy - vì vào lứa tuổi dậy thì, cơ thể bị thiếu vitamin B5 (còn có tên là acid pantotenic). Tóc chịu nhiều ảnh hưởng của các yếu tố thần kinh, nội tiết, dinh dưỡng, đặc biệt là vitamin B5. Nhu cầu về vitamin B5 của cơ thể được cung cấp đủ bởi một chế độ ăn bình thường, cân đối. Nhưng đến tuổi dậy thì, rất nhiều bộ phận trong cơ thể phát triển mạnh (tuyến vú, mông, cơ quan sinh dục...) nên tiêu thụ nhiều vitamin B5 hơn, mà thức ăn hằng ngày không đủ cung cấp. Hậu quả là tóc, đặc biệt nhú tóc bị thiếu vitamin B5 nên ngừng mọc và rụng nhiều.Như vậy các em ở tuổi dậy thì nếu tự nhiên thấy rụng nhiều tóc, khiến cho mật độ tóc giảm hẳn đi thì cần nghĩ tới việc thiếu hụt vitamin B5. Muốn chống rụng tóc, khẩu phần dinh dưỡng hằng ngày cần tăng thêm loại vitamin này.Vitamin B5 có nhiều trong tự nhiên (từ Hy Lạp pantotenic nghĩa là có ở khắp nơi). Những thực phẩm có nhiều vitamin B5 là: đậu phộng, các loại đậu đỗ, lòng trắng trứng, các loại nấm, thịt gia súc gia cầm... Sau 2-3 tháng, khi các nhú tóc ở lớp da đầu đã được cung cấp đủ vitamin B5, tóc sẽ bớt rụng và mọc thêm.Trong trường hợp rụng tóc quá nhiều, cháu nên đến khám bác sĩ; Có thể bác sĩ sẽ cho dùng thuốc vitamin B5 với các biệt dược như Bepanthène, Beducene, Pantenyl...\n\n'

# %% [markdown]
# ## Preprocess

# %%
import re
from nltk import word_tokenize, sent_tokenize
import string
from tqdm import tqdm

def tokenize(doc):
    tokens = word_tokenize(doc.lower())
    table = str.maketrans('', '', string.punctuation.replace("_", "")) 
    tokens = [w.translate(table) for w in tokens]
    tokens = [word for word in tokens if word]
    return tokens

full_data = ". ".join(full)
full_data = full_data.replace("\n", ". ")
corpus = []
sents = re.split(r'(?<=[^A-Z].[.?]) +(?=[A-Z])', full_data)
for sent in tqdm(sents):
    corpus.append(tokenize(sent))
# Out:
# 100%|██████████| 738597/738597 [03:56<00:00, 3121.34it/s]

# %%
print(len(corpus))
for c in corpus[:10]:
    print(c)
# Out:
# 738597
# ['trao', 'giải', 'cuộc', 'thi', 'an', 'toàn', 'giao', 'thông', 'cho', 'giới', 'trẻ']
# ['sáng', 'nay', 'báo', 'sinh', 'viên', 'việt', 'nam', 'và', 'ngân', 'hàng', 'phát', 'triển', 'châu', 'á', 'adb', 'đã', 'trao', 'giải', 'thưởng', 'cho', 'các', 'tác', 'giả', 'đoạt', 'giải', 'cuộc', 'thi', 'viết', 'về', 'an', 'toàn', 'giao', 'thông', 'mang', 'tên', 'hành', 'trình', 'khó', 'quên']
# ['cuộc', 'thi', 'này', 'thu', 'hút', 'hơn', '5800', 'bài', 'dự', 'thi', 'của', 'học', 'sinh', 'sinh', 'viên', 'các', 'trường', 'trên', 'địa', 'bàn', 'hà', 'nội']
# ['giải', 'nhất', 'trị', 'giá', '5', 'triệu', 'đồng', 'đã', 'được', 'trao', 'cho', 'em', 'nguyễn', 'khánh', 'dương', 'đại', 'học', 'sư', 'phạm', 'với', 'bài', 'viết', 'hành', 'trình', 'tình', 'nguyện']
# ['câu', 'chuyện', 'của', 'dương', 'kể', 'lại', 'một', 'buổi', 'chiều', 'trên', 'đường', 'về', 'nhà', 'em', 'đã', 'gặp', 'cảnh', 'ùn', 'tắc', 'giao', 'thông', 'tại', 'nút', 'daewoo', 'kim', 'mã', 'đang', 'khoác', 'trên', 'người', 'chiếc', 'áo', 'xanh', 'tình', 'nguyện', 'dương', 'nhanh', 'chóng', 'nảy', 'ra', 'ý', 'tưởng', 'phải', 'giúp', 'mọi', 'người', 'đi', 'đúng', 'đường', 'giải', 'quyết', 'ùn', 'tắc']
# ['em', 'đã', 'cùng', '2', 'bạn', 'khác', 'xuống', 'xe', 'đứng', 'giữa', 'đường', 'phân', 'luồng', 'cho', 'đến', 'khi', 'tuyến', 'đường', 'được', 'khai', 'thông']
# ['dương', 'cho', 'hay', 'đó', 'là', 'lần', 'đầu', 'tiên', 'em', 'tự', 'tham', 'gia', 'phân', 'luồng', 'giao', 'thông', 'tuy', 'hồi', 'hộp', 'song', 'rất', 'phấn', 'khởi', 'là', 'mọi', 'người', 'đã', 'chấp', 'hành', 'nghiêm', 'chỉnh', 'theo', 'chỉ', 'dẫn', 'của', 'em', 'nên', 'đoạn', 'đường', 'được', 'thông']
# ['viết', 'bài', 'dự', 'thi', 'là', 'em', 'muốn', 'truyền', 'tinh', 'thần', 'tình', 'nguyện', 'của', 'các', 'bạn', 'trẻ', 'tới', 'cộng', 'đồng', 'dương', 'nói']
# ['ban', 'tổ', 'chức', 'còn', 'trao', '2', 'giải', 'nhì', '3', 'giải', 'ba', '4', 'giải', 'khuyến', 'khích']
# ['bài', 'được', 'giải', 'đều', 'là', 'những', 'mẩu', 'chuyện', 'nhỏ', 'mô', 'tả', 'sinh', 'động', 'những', 'tình', 'huống', 'giao', 'thông', 'thực', 'tế', 'hay', 'những', 'bài', 'học', 'khi', 'vi', 'phạm', 'luật', 'giao', 'thông']

# %% [markdown]
# ## Train model

# %%
from nltk.lm.preprocessing import padded_everygram_pipeline
from nltk.lm import MLE, Laplace, KneserNeyInterpolated, WittenBellInterpolated
import pickle
import os 

n = 3
vi_model = KneserNeyInterpolated(n)

train_data, padded_sents = padded_everygram_pipeline(n, corpus)
vi_model.fit(train_data, padded_sents)
print(len(vi_model.vocab))

model_dir = "/content/drive/My Drive/Colab Notebooks/Ngram_model"
with open(os.path.join(model_dir, 'kneserney_1st_ngram_model.pkl'), 'wb') as fout:
    pickle.dump(vi_model, fout)
# Out:
# 104813

# %%
# Test to get logscore
print(vi_model.logscore('nam', ['sinh', 'việt']))
print(vi_model.logscore('nam', ['sinh', 'chuỹen']))
print(vi_model.logscore('nam', ['việt']))
# Out:
# -0.008768946173740685
# -16.677458140476162
# -0.4283570725364177

# %%
from nltk.tokenize.treebank import TreebankWordDetokenizer
detokenize = TreebankWordDetokenizer().detokenize
def generate_sent(model, num_words, pre_words=[]):
    content = pre_words
    for i in range(num_words):
        token = model.generate(1, text_seed=content[-2:])
        if token == '<s>':
            continue
        if token == '</s>':
            break
        content.append(token)
    return detokenize(content)

generate_sent(vi_model, 10, ["đất", "nước"])
# Out:
# 'đất nước việt nam các phương tiện như ở vn sử dụng'

# %% [markdown]
# # Bài 2: (optional)
#
# ### Viết lại thuật toán tính Bleu score, là thuật toán đo độ tương tự giữa 2 câu:
#
# ### https://en.wikipedia.org/wiki/BLEU

# %%
def n_gram_generator(sentence,n= 2,n_gram= False):
    sentence = sentence.lower()
    sent_arr = np.array(sentence.split())
    length = len(sent_arr)
    word_list = []
    for i in range(length+1):
        if i < n:
            continue
        word_range = list(range(i-n,i))
        s_list = sent_arr[word_range]
        string = ' '.join(s_list) 
        word_list.append(string)
        if n_gram:
            word_list = list(set(word_list))
    return word_list

# %%
def bleu_score(original, machine_translated):
    mt_length = len(machine_translated.split())
    o_length  = len(original.split())
    if mt_length > o_length:
        BP=1
    else:
        penality=1-(mt_length/o_length)
        BP = np.exp(penality)
    clipped_precision_score = []
    for ngram_level in range(1, 5):  
        original_ngram_list = n_gram_generator(original, ngram_level)
        original_n_gram = Counter(original_ngram_list)      
        machine_ngram_list = n_gram_generator(machine_translated, ngram_level)
        machine_n_gram = Counter(machine_ngram_list)
        num_ngrams_in_translation = sum(machine_n_gram.values()) 
        for j in machine_n_gram:
            if j in original_n_gram:  
                if machine_n_gram[j] > original_n_gram[j]: 
                    machine_n_gram[j] = original_n_gram[j]      
            else:
                machine_n_gram[j] = 0
        clipped_precision_score.append(float(sum(machine_n_gram.values())) / num_ngrams_in_translation)
    weights = [0.25]*4

    s = (w_i * math.log(p_i) for w_i, p_i in zip(weights, clipped_precision_score))
    s = BP * math.exp(math.fsum(s))
    return s

# %%
if __name__ == "__main__":
  raw = "It is a guide to action which ensures that the military alwasy obeys the command of the party"
  test = "It is the guiding principle which guarantees the military forces alwasy being under the command of the party"
  print ("bleu_score:",bleu_score(raw, test))
  print ("sentence_bleu:",sentence_bleu([raw.split()], test.split()))
# Out:
# bleu_score: 0.27098211583470044
# sentence_bleu: 0.27098211583470044
